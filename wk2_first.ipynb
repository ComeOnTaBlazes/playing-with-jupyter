# %% [markdown]
# #### Created when watching lectures
# #### For numpy package
#
# [Official documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
#
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Change the default figure size
plt.rcParams['figure.figsize'] = [12, 8]

# %%
#change the default stylesheet
plt.style.use('fivethirtyeight')

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# see first 10 items in s
s[:10]
# Out:
# array([-0.02803946, -0.02446774, -0.09364079, -0.11537083, -0.07273012,
#         0.03370868,  0.05672603,  0.02985384,  0.04855419, -0.04848102])

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2/(2 * sigma**2))
plt.plot(bins, f, linewidth=2, )
plt.show()

# %% [markdown]
# ### Python style guide
#
# https://www.python.org/dev/peps/pep-0008/

# %% [markdown]
# ***
# ### References
# 1. https://numpy.org/doc/stable/reference/random/index.html
